# %%
import pandas as pd
import psycopg2
import dotenv
import os

dotenv.load_dotenv()

PG_PASSWORD = os.getenv("PG_PASSWORD")
PG_USER = os.getenv("PG_USER")
PG_HOST = os.getenv("PG_HOST")
PG_PORT = os.getenv("PG_PORT")
PG_DATABASE = os.getenv("PG_DB")

# Database connection parameters
import psycopg2
import os

conn = psycopg2.connect(
    host=PG_HOST,
    database=PG_DATABASE,
    user=PG_USER,
    password=PG_PASSWORD,
    port=PG_PORT,
    sslmode="require",
)

# %% [markdown]
# For all games ever

# %%
import pandas as pd

# Get the distinct game_ids from the id_df
id_query = """
SELECT DISTINCT game_id 
FROM spadl_actions a
JOIN matches m ON game_id = match_id
"""
id_df = pd.read_sql_query(id_query, conn)

# Prepare the base complex query, using a placeholder for game_id
complex_query = """
WITH action_changes AS (
    SELECT
        a.*,
        LAG(a.team_id) OVER (ORDER BY a.period_id, a.seconds, a.id) AS prev_team_id,
        LEAD(a.team_id) OVER (ORDER BY a.period_id, a.seconds, a.id) AS next_team_id
    FROM
        spadl_actions a
    WHERE
        a.game_id = '{game_id}'
),
possession_markers AS (
    SELECT
        *,
        CASE WHEN prev_team_id IS NULL OR team_id != prev_team_id THEN 1 ELSE 0 END AS is_new_possession
    FROM
        action_changes
),
possession_sequences AS (
    SELECT
        *,
        SUM(is_new_possession) OVER (ORDER BY period_id, seconds, id) AS possession_group
    FROM
        possession_markers
),
possession_stats AS (
    SELECT
        possession_group,
        team_id,
        COUNT(*) AS action_count,
        MAX(id) AS last_action_id
    FROM
        possession_sequences
    GROUP BY
        possession_group, team_id
)
SELECT 
    ps.id, 
    ps.seconds, 
    ps.player_id, 
    ps.team_id, 
    t.team_name, 
    p.player_name, 
    ps.action_type, 
    ps.result, 
    ps.possession_group
FROM 
    possession_sequences ps
JOIN 
    teams t ON ps.team_id = t.team_id
JOIN 
    players p ON ps.player_id = p.player_id
"""

# Initialize an empty list to store the dataframes
all_possession_data = []

# Iterate over each game_id in id_df and execute the complex query for each game
for game_id in id_df['game_id']:
    # Substitute the game_id in the complex query
    query_with_game_id = complex_query.format(game_id=game_id)
    
    # Execute the query and get the results
    possession_df = pd.read_sql_query(query_with_game_id, conn)
    
    # Append the results to the list
    all_possession_data.append(possession_df)
    
    # Optional: Print progress
    print(f"Loaded data for game_id {game_id}, {len(possession_df)} rows")

# Concatenate all the dataframes into one
final_possession_df = pd.concat(all_possession_data, ignore_index=True)

# Save the final DataFrame to a CSV file
csv_file_path = 'possession_data.csv'
final_possession_df.to_csv(csv_file_path, index=False)

# Print confirmation
print(f"Data saved to {csv_file_path}")

# %% [markdown]
# For gantt matches with sequences

# %%
import pandas as pd

# Get the distinct game_ids from the id_df
id_query = """
SELECT DISTINCT game_id 
FROM spadl_actions a
JOIN matches m ON game_id = match_id
"""
id_df = pd.read_sql_query(id_query, conn)

# Prepare the base complex query, using a placeholder for game_id
complex_query = """
WITH action_changes AS (
    SELECT
        a.*,
        LAG(a.team_id) OVER (ORDER BY a.period_id, a.seconds, a.id) AS prev_team_id,
        LEAD(a.team_id) OVER (ORDER BY a.period_id, a.seconds, a.id) AS next_team_id
    FROM
        spadl_actions a
    WHERE
        a.game_id = '{game_id}'
),
possession_markers AS (
    SELECT
        *,
        CASE WHEN prev_team_id IS NULL OR team_id != prev_team_id THEN 1 ELSE 0 END AS is_new_possession
    FROM
        action_changes
),
possession_sequences AS (
    SELECT
        *,
        SUM(is_new_possession) OVER (ORDER BY period_id, seconds, id) AS possession_group
    FROM
        possession_markers
),
possession_stats AS (
    SELECT
        possession_group,
        team_id,
        COUNT(*) AS action_count,
        MAX(id) AS last_action_id
    FROM
        possession_sequences
    GROUP BY
        possession_group, team_id
)
SELECT 
    ps.id, 
    ps.seconds, 
    ps.player_id, 
    ps.team_id, 
    t.team_name, 
    p.player_name, 
    ps.action_type, 
    ps.result, 
    ps.possession_group
FROM 
    possession_sequences ps
JOIN 
    teams t ON ps.team_id = t.team_id
JOIN 
    players p ON ps.player_id = p.player_id
"""

# Initialize an empty list to store the dataframes
all_possession_data = []

# Iterate over each game_id in id_df and execute the complex query for each game
for game_id in id_df['game_id']:
    # Substitute the game_id in the complex query
    query_with_game_id = complex_query.format(game_id=game_id)
    
    # Execute the query and get the results
    possession_df = pd.read_sql_query(query_with_game_id, conn)
    
    # Filter the results to include only the rows where team_id is '8y3iucyxguipljcmf87a11bk9'
    possession_df = possession_df[possession_df['team_id'] == '8y3iucyxguipljcmf87a11bk9']
    
    # Append the filtered results to the list
    all_possession_data.append(possession_df)
    
    # Optional: Print progress
    print(f"Loaded data for game_id {game_id}, {len(possession_df)} rows after filtering")

# Concatenate all the dataframes into one
final_possession_df = pd.concat(all_possession_data, ignore_index=True)

# Save the final DataFrame to a CSV file
csv_file_path = 'possession_data_filtered.csv'
final_possession_df.to_csv(csv_file_path, index=False)

# Print confirmation
print(f"Data saved to {csv_file_path}")
# Out:
# C:\Users\Gytis\AppData\Local\Temp\ipykernel_13228\899566789.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   id_df = pd.read_sql_query(id_query, conn)
# C:\Users\Gytis\AppData\Local\Temp\ipykernel_13228\899566789.py:75: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   possession_df = pd.read_sql_query(query_with_game_id, conn)
# Loaded data for game_id 5oc8drrbruovbuiriyhdyiyok, 0 rows after filtering
# Loaded data for game_id 5ow2wa823rjft38oh48b4ror8, 0 rows after filtering
# Loaded data for game_id 5pcyhm34h5c948yji4oryevpw, 0 rows after filtering
# Loaded data for game_id 5ptnar4qtaltvcfsjdw9vzhg4, 0 rows after filtering
# Loaded data for game_id 5qa6smqwjobwdm3j0okr0r09g, 0 rows after filtering
# Loaded data for game_id 5qqz2do47zjms7rfrwzcths7o, 1097 rows after filtering
# Loaded data for game_id 5r7lyj3frtml3aqy458jrxj4k, 0 rows after filtering
# Loaded data for game_id 5ro450tmjg6o1r4cphzzyg74k, 0 rows after filtering
# Loaded data for game_id 5sue6595uizdrssh0wv22egpg, 0 rows after filtering
# Loaded data for game_id 5t7w35uh3t29uk7t0egu7q784, 0 rows after filtering
# Loaded data for game_id 5tle8ulixbd5vc0y4p7myvrbo, 0 rows after filtering
# Loaded data for game_id 5u35bb21cuumrm2th8czyecr8, 0 rows after filtering
# Loaded data for game_id 5ugfsw7je1y0lay7xdqe3pces, 0 rows after filtering
# Loaded data for game_id 5uts2s7fl98clqz8uymaazehg, 1303 rows after filtering
# Loaded data for game_id 5v736sblloyh7f2kblxoqni8k, 0 rows after filtering
# Loaded data for game_id 5vkgr4htjs4t0r0zj6gprk1zo, 0 rows after filtering
# Loaded data for game_id 5vxo6e7c495zmi951vfdf8vtg, 0 rows after filtering
# Loaded data for game_id 5wb56hj1k3gel6lkn5se3gqok, 0 rows after filtering
# Loaded data for game_id 5wofhz4hm81f0lk0ay8sumfis, 0 rows after filtering
# Loaded data for game_id 5x3j66bwrma8tfs8yyohzgob8, 0 rows after filtering
# Loaded data for game_id 5xgwfzcgrnw085pw5hnepeln8, 894 rows after filtering
# Loaded data for game_id 5xud4wolwm30f88iddht6tnh0, 0 rows after filtering
# Loaded data for game_id 5y7o12321gsyhahz2gn9k70gk, 0 rows after filtering
# Loaded data for game_id 5yl234veeetrulf3elt6ietck, 0 rows after filtering
# Loaded data for game_id 5yydugt5i41swnxgud348ujh0, 0 rows after filtering
# Loaded data for game_id 5zbqst62v7epoh0ujqact9fys, 0 rows after filtering
# Loaded data for game_id 5zp7fogt8mcrca2oitkedqvbo, 0 rows after filtering
# Loaded data for game_id 602pbgoexz07st4msln8fq0wk, 0 rows after filtering
# Loaded data for game_id 60fxqypp88be80w75i4zeytxw, 0 rows after filtering
# Loaded data for game_id 60t776say1yeeo1fsxk4wanmc, 800 rows after filtering
# Loaded data for game_id 616kggdv0monqet88gm079tsk, 0 rows after filtering
# Loaded data for game_id 61k08idj2sikh13zinspq2oes, 775 rows after filtering
# Loaded data for game_id 61xmh1s2xtwsx4noo7sqj6k2c, 0 rows after filtering
# Loaded data for game_id 62cnaajosb1s3o89q0lc26cd0, 0 rows after filtering
# Loaded data for game_id 62q3i7358pd2cj5ifdo4evtp0, 0 rows after filtering
# Loaded data for game_id 633kfo3pvp46mgpidjadmzg2c, 0 rows after filtering
# Loaded data for game_id 63h4h13tk4qc892q7gjrd5s0k, 0 rows after filtering
# Loaded data for game_id 63uoo18inmfae3rccfpuza5n8, 0 rows after filtering
# Loaded data for game_id 647zcbpkdxjcdxni44n10at5g, 0 rows after filtering
# Loaded data for game_id 64lht6g6ibxn6bagltwfy96ac, 0 rows after filtering
# Loaded data for game_id 64ysv2thjjl53plej04r8jxuc, 0 rows after filtering
# Loaded data for game_id 65chj645tcu0gtoy18rdroyz8, 0 rows after filtering
# Loaded data for game_id 65q09fgzt687cupdrb83y8qhg, 0 rows after filtering
# Loaded data for game_id 663g37c8m2xo51oc1p9qgv8r8, 814 rows after filtering
# Loaded data for game_id 66gwllyydpsz7dx3yxkxq9ixg, 0 rows after filtering
# Loaded data for game_id 66ucfra4d6i3l0xcgxq1ubsb8, 0 rows after filtering
# Loaded data for game_id 679h1gg8f915oon195pljkg7o, 0 rows after filtering
# Loaded data for game_id 67nhr0xxxzjqk6w7c0gmrf11w, 0 rows after filtering
# Loaded data for game_id 680xcwtdpjmrp0slvty9jf09g, 0 rows after filtering
# Loaded data for game_id 68eiweirqknjn592234u1xlw4, 0 rows after filtering
# Loaded data for game_id 68sa9uu43xr57i0g660kjerkk, 0 rows after filtering
# Loaded data for game_id 695t6yuiyw8q7bjv9nnll1atw, 0 rows after filtering
# Loaded data for game_id 69j7bcf7os8kbk36hu1uwf9jo, 0 rows after filtering
# Loaded data for game_id 69wrieh1ixcw51mu3bt111bmc, 950 rows after filtering
# Loaded data for game_id 6aaebu7uj50ewu3irl3qmjg2c, 616 rows after filtering
# Loaded data for game_id 6ao2gvyiimquw8dlhisfsd2j8, 0 rows after filtering
# Loaded data for game_id 6b206zumfxuvxldwrgh54waok, 0 rows after filtering
# Loaded data for game_id 6bfrz2jq6km4wkxuqtscmzgus, 0 rows after filtering
# Loaded data for game_id 6btbspj3kkhpcjd3dkbag29sk, 0 rows after filtering
# Loaded data for game_id 6c8lz4vpdfl8yxo9kgokz9250, 0 rows after filtering
# Loaded data for game_id 6cm7emcjcoyv5sx865wkovrpw, 0 rows after filtering
# Loaded data for game_id 6czy554xx6z1xpgn636ml8x04, 0 rows after filtering
# Loaded data for game_id 6ddnhqps3jpvpthkwmpo00h04, 0 rows after filtering
# Loaded data for game_id 6drdicnjxpb4gc279bogttjpw, 0 rows after filtering
# Loaded data for game_id 6e51m1j7b2y8ycmgv0h215c7o, 753 rows after filtering
# Loaded data for game_id 6eitft1h5nkids5d1ebh4scgk, 0 rows after filtering
# Loaded data for game_id 6ewi4e9do7gx7hmm5ser4idqs, 0 rows after filtering
# Loaded data for game_id 6fal3n71n68p9j1pypcdabggk, 0 rows after filtering
# Loaded data for game_id 6foamr1y4x3t549lo89xczuok, 0 rows after filtering
# Loaded data for game_id 6g25sma115dj07dydvw82c4yc, 0 rows after filtering
# Loaded data for game_id 6gfytd52ib44k8sm0pc8lohzo, 0 rows after filtering
# Loaded data for game_id 6gtvcij4wvinji2yhjopmq87o, 0 rows after filtering
# Loaded data for game_id 6h7k7hc45o9r2wva0jr055vys, 0 rows after filtering
# Loaded data for game_id 6hn66x6v2vitdluzbhdmj55hw, 0 rows after filtering
# Loaded data for game_id 6i180b3iyx583di6at041k4r8, 0 rows after filtering
# Loaded data for game_id 6if57plgmp488phm11gbxvx1w, 949 rows after filtering
# Loaded data for game_id 6it98lfd592zqlhj33bvm6iok, 0 rows after filtering
# Loaded data for game_id 6j7t38109kev3yht9gfv7oopg, 0 rows after filtering
# Loaded data for game_id 6jlrinuzb0udhcixas2e9fh90, 996 rows after filtering
# Loaded data for game_id 6k4lyfjs03qtvuqwq3zaz3eac, 0 rows after filtering
# Loaded data for game_id 6kihp4rm8xn1dqub6a6je8bh0, 0 rows after filtering
# Loaded data for game_id 6kwgeb5ynmu4tui1iqnhbmihg, 0 rows after filtering
# Loaded data for game_id 6laud87o2272y9txxwvok2n84, 0 rows after filtering
# Loaded data for game_id 6lop4d01krcoktw7peu0xrlec, 0 rows after filtering
# Loaded data for game_id 6m2mih17gly2exfux0wczv09g, 0 rows after filtering
# Loaded data for game_id 6mg96jofsxv3y2z8whcdtzeok, 0 rows after filtering
# Loaded data for game_id 6mvh0ixx6p3frjttob5szqcr8, 0 rows after filtering
# Loaded data for game_id 6n8z4gyo5m3xo8sz52sbmuec4, 0 rows after filtering
# Loaded data for game_id 6nmjerq63j2zi7v7ee42jay38, 796 rows after filtering
# Loaded data for game_id 6o09zz4g7u6d6hsx0725wq32s, 0 rows after filtering
# Loaded data for game_id 6odsz1jovznuwxmhla5r4cums, 0 rows after filtering
# Loaded data for game_id 6orczmljkia5qp7w6swg9dus4, 0 rows after filtering
# Loaded data for game_id 6p4xcllb1x7vx1xljrk14gbh0, 0 rows after filtering
# Loaded data for game_id 6pifzverlaou1inrkx8uji238, 0 rows after filtering
# Loaded data for game_id 6pw6lftlu8kg9zjv2o5qy90r8, 0 rows after filtering
# Loaded data for game_id 6q9v7t10ucc22wfrevv47ifis, 0 rows after filtering
# Loaded data for game_id 6qnjfizydc16eodb8gvnbxyxg, 0 rows after filtering
# Loaded data for game_id 6r1jnaqq7lo6jy9akecdtxnh0, 1093 rows after filtering
# Loaded data for game_id 6rf9c1ijlg0dgz94f54bii4no, 0 rows after filtering
# Loaded data for game_id 6rulhyb9xa5yczi1jntilsr9w, 0 rows after filtering
# Loaded data for game_id 6sfzz7fdc8ihyiwgsvbo09s0k, 0 rows after filtering
# Loaded data for game_id 6sto74fs8y40cyntz0hgci51w, 0 rows after filtering
# Loaded data for game_id 6t7akwoa8n6jp6buko1cbwges, 0 rows after filtering
# Loaded data for game_id 6tkwztvlcw16dlq2ao2pxrx90, 888 rows after filtering
# Loaded data for game_id 6tyl33e6t299mje0886r16a6s, 0 rows after filtering
# Loaded data for game_id 6uc41ha2woe8uz2y69t44j5ec, 0 rows after filtering
# Loaded data for game_id 6upsxcxz9i0i2t2envvxndbf8, 0 rows after filtering
# Loaded data for game_id 6v3czxoqwz8yqy6nq0h8mqc5w, 0 rows after filtering
# Loaded data for game_id 6vgw3pyau8qobs1lbvcc5spp0, 0 rows after filtering
# Loaded data for game_id 6vul2r4nef60spfw1s0m9nwno, 0 rows after filtering
# Loaded data for game_id 6w85l67ix6a5ggn6d8fnsvlec, 0 rows after filtering
# Loaded data for game_id 6wlur9am96azmgxpyyhu9ocgk, 636 rows after filtering
# Loaded data for game_id 6wzxavsdufibu29eig0c7nfo4, 0 rows after filtering
# Loaded data for game_id 6xgdqaeuf3hro487ukl7ldq1g, 0 rows after filtering
# Loaded data for game_id 6xuduo3wzk7bv93egsuuc5t04, 0 rows after filtering
# Loaded data for game_id 6y80kic6abtlkzmkr4oiejkt0, 0 rows after filtering
# Loaded data for game_id 6ymsvd6swsb0ozlav7sq4v1n8, 0 rows after filtering
# Loaded data for game_id 6z0i3t71vcbys6wizbqnrdlp0, 0 rows after filtering
# Loaded data for game_id 6ze0088jxji9lprilgrzp6xw4, 0 rows after filtering
# Loaded data for game_id 6zrmzdgg5dvdmghjcyp698pw4, 0 rows after filtering
# Loaded data for game_id 705dctz9vetc2ebh48nglch04, 0 rows after filtering
# Loaded data for game_id 70wtfxx5kccxl5sxj1bvcd8us, 0 rows after filtering
# Loaded data for game_id 71pqoqka3xv6owqcnqzwdaeqc, 748 rows after filtering
# Loaded data for game_id 72w7f59fd9ptg7x3jp8sikqok, 0 rows after filtering
# Loaded data for game_id 739yhpejnygm1rpbqsllnrg9g, 787 rows after filtering
# Loaded data for game_id 73o1xp3vkarsqlbpfz8stprtg, 0 rows after filtering
# Loaded data for game_id 741sm8f1osrj6qvq54ql5sv84, 0 rows after filtering
# Loaded data for game_id 74fg5ak3m9a9n8u7ip5u56t5g, 0 rows after filtering
# Loaded data for game_id 74t2y9nrjhwi275vjtdxyfpqs, 0 rows after filtering
# Loaded data for game_id 756u46khy7yhi4q7hljt6i8lw, 0 rows after filtering
# Loaded data for game_id 75kds3fqjpbc599rjl996vhuc, 0 rows after filtering
# Loaded data for game_id 75xyj0hlct5wqv6uamxf8c1ec, 0 rows after filtering
# Loaded data for game_id 77334kljwhvl2ogfwmbqmjspg, 0 rows after filtering
# Loaded data for game_id 77idfj6cmoadi2223efythatw, 0 rows after filtering
# Loaded data for game_id 77w03jwg8cs1dkqemcax540t0, 0 rows after filtering
# Loaded data for game_id 789p8p9wchivsno0m437haeqc, 0 rows after filtering
# Loaded data for game_id 78nndczlbj2214zhtbfahs2s4, 0 rows after filtering
# Data saved to possession_data_filtered.csv

# %% [markdown]
# File maker for "period_id","seconds","start_x","start_y","end_x","end_y","action_type","result","possession_group"

# %%
import pandas as pd

# Get the distinct game_ids from the id_df
id_query = """
SELECT DISTINCT game_id 
FROM spadl_actions a
JOIN matches m ON game_id = match_id
"""
id_df = pd.read_sql_query(id_query, conn)

# Prepare the base complex query, using a placeholder for game_id
complex_query = """
WITH action_changes AS (
    SELECT
        a.*,
        LAG(a.team_id) OVER (ORDER BY a.period_id, a.seconds, a.id) AS prev_team_id,
        LEAD(a.team_id) OVER (ORDER BY a.period_id, a.seconds, a.id) AS next_team_id
    FROM
        spadl_actions a
    WHERE
        a.game_id = '{game_id}'
),
possession_markers AS (
    SELECT
        *,
        CASE WHEN prev_team_id IS NULL OR team_id != prev_team_id THEN 1 ELSE 0 END AS is_new_possession
    FROM
        action_changes
),
possession_sequences AS (
    SELECT
        *,
        SUM(is_new_possession) OVER (ORDER BY period_id, seconds, id) AS possession_group
    FROM
        possession_markers
),
possession_stats AS (
    SELECT
        possession_group,
        team_id,
        COUNT(*) AS action_count,
        MAX(id) AS last_action_id
    FROM
        possession_sequences
    GROUP BY
        possession_group, team_id
)
SELECT 
    ps.period_id,
    ps.seconds, 
    ps.start_x,
    ps.start_y, 
    ps.end_x, 
    ps.end_y, 
    ps.action_type, 
    ps.result, 
    ps.possession_group
FROM 
    possession_sequences ps
JOIN 
    teams t ON ps.team_id = t.team_id
JOIN 
    players p ON ps.player_id = p.player_id
"""

# Initialize an empty list to store the dataframes
all_possession_data = []

# Iterate over each game_id in id_df and execute the complex query for each game
for game_id in id_df['game_id']:
    # Substitute the game_id in the complex query
    query_with_game_id = complex_query.format(game_id=game_id)
    
    # Execute the query and get the results
    possession_df = pd.read_sql_query(query_with_game_id, conn)
    
    # Filter the results to include only the rows where team_id is '8y3iucyxguipljcmf87a11bk9'
    possession_df = possession_df[possession_df['team_id'] == '8y3iucyxguipljcmf87a11bk9']
    
    # Append the filtered results to the list
    all_possession_data.append(possession_df)
    
    # Optional: Print progress
    print(f"Loaded data for game_id {game_id}, {len(possession_df)} rows after filtering")

# Concatenate all the dataframes into one
final_possession_df = pd.concat(all_possession_data, ignore_index=True)

# Save the final DataFrame to a CSV file
csv_file_path = 'possession_data_filtered.csv'
final_possession_df.to_csv(csv_file_path, index=False)

# Print confirmation
print(f"Data saved to {csv_file_path}")
